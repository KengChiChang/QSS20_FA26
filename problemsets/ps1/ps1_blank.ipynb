# %% [markdown]
# # Problem Set 1: Who Gets Searched at a Traffic Stop?
#
# QSS 20 · Modern Statistical Computing · Fall 2026

# %% [markdown]
# **Out:** Thursday, September 24 · **Due:** Thursday, October 1, 11:59pm

# %% [markdown]
# ## Overview
#
# A traffic stop is the most common way Americans meet the police. Most stops
# end with a warning or a ticket. Some become searches, and whether a search
# happens is an officer's judgment call. For decades, drivers and civil-rights
# groups have argued that this judgment falls harder on Black and Hispanic
# drivers; departments have answered that officers respond to behavior, not
# race. This argument can be examined with data, because departments record
# millions of stops.
#
# You will analyze **3.6 million traffic stops** from three cities, 2010
# through 2015, standardized by the Stanford Open Policing Project: San
# Francisco, Charlotte, and Nashville. You will utilize what you learned so
# far: audit files from the command line, select rows with pandas, aggregate
# with `groupby`, and automate the same analysis across several files.
# You can then compare **search rates** and **hit rates** across cities.
#
# **Submission.** Copy `ps1_blank.ipynb` as `ps1_mywork.ipynb` and work in it.
# Keep `{{{< pagebreak >}}}` so page tagging on Gradescope stays simple.
# Once you're finished, click "Kernel", "Restart Kernel and Clear Outputs
# of All Cells", and then "Restart Kernel and Run All Cells", then
# export your notebook to PDF with
# `quarto render ps1_mywork.ipynb --to typst`.
# Upload `ps1_mywork.ipynb` and `ps1_mywork.pdf` to Gradescope.
#
# **Data.** Three compressed files sit in `data/raw/`, one per city, named
# like `san_francisco_stops_2010_2015.csv.gz`. One row is one vehicular stop.
# The shared fields:
#
# | Field | Meaning |
# |---|---|
# | `date`, `time` | when the stop happened |
# | `subject_age`, `subject_race`, `subject_sex` | the stopped driver, as recorded by the officer |
# | `outcome` | most severe result: `warning`, `citation`, or `arrest` |
# | `arrest_made`, `citation_issued`, `warning_issued` | outcome indicators |
# | `search_conducted` | True if the officer searched the person or vehicle |
# | `contraband_found` | for searched stops: True if the search found contraband |
#
# These files are compressed with gzip. pandas can read them directly
# (`pd.read_csv("file.csv.gz")`). In the command line, you can use
# `gunzip -c file.csv.gz` to print out uncompressed text.
# You can combine it with the `|` pipe learned in class:
# `gunzip -c file.csv.gz | head`.

# %%
import glob
import pandas as pd
DATA = "data/raw"

# %% [markdown]
# {{< pagebreak >}}

# %% [markdown]
# ## 1. Audit the files from the shell (14 points)
#
# Do this section before any Python.

# %% [markdown]
# **1.1 (7 points).** Report two things for each of the three files: its
# compressed and uncompressed size, and its number of lines. `gzip -l` gives
# the sizes for all three in one command. For the line counts, counting one
# file at a time gets old at three files and hopeless at three hundred, so
# write **one shell loop**:
#
# ```bash
# for f in data/raw/*.csv.gz; do
#   echo "$f: $(gunzip -c "$f" | wc -l) lines"
# done
# ```
#
# Paste both commands and their output, then state the number of **data rows**
# per city.

# %% [markdown]
# {{< pagebreak >}}

# %% [markdown]
# **1.2 (7 points).** Print the header and first two data rows of the San
# Francisco file with one pipeline. Do the three files promise the same
# columns? Check and answer in one sentence. Then name one question about this
# data that the shell **cannot** answer.

# %% [markdown]
# {{< pagebreak >}}

# %% [markdown]
# ## 2. Load one city and read its shape (12 points)
#
# Work with **San Francisco** in Sections 2 through 4.

# %% [markdown]
# **2.1 (6 points).** Load the file with pandas. Report rows, columns, and
# each column's dtype.

# %% [markdown]
# {{< pagebreak >}}

# %% [markdown]
# **2.2 (6 points).** Two checks on that table, with supporting output for
# each. First, `search_conducted` is `bool` but `contraband_found` is
# `object`: what values does `contraband_found` take, and what does missing
# mean for that field? Second, verify the file matches its name by printing
# the minimum and maximum `date`, and report how many stops have no recorded
# `subject_age`.

# %% [markdown]
# {{< pagebreak >}}

# %% [markdown]
# ## 3. Select the rows you mean (16 points)
#
# Each task: build the selection, then **audit it** by printing the values or
# ranges that prove the filter did what you claim.

# %% [markdown]
# **3.1 (8 points).** Select stops of drivers **under 25**. Report how many
# there are and what share of all stops, and print the selected ages'
# minimum and maximum as the audit.

# %% [markdown]
# {{< pagebreak >}}

# %% [markdown]
# **3.2 (8 points).** Parse `date` with `pd.to_datetime`, then select the
# stops from **2013 through 2015** using `.between`. Report the count and
# audit with the selected minimum and maximum dates. Then use `.isin` to add a
# second condition, that the outcome was a `warning` or a `citation`, and
# combine both conditions in one mask. How many stops satisfy both? Audit with
# `.unique()` on the selected outcomes and with the selected dates.

# %% [markdown]
# {{< pagebreak >}}

# %% [markdown]
# ## 4. Aggregate: search rates and hit rates (22 points)

# %% [markdown]
# **4.1 (8 points).** Build one table with one row per `subject_race` and two
# named columns: `stops` (row count) and `search_rate` (the mean of
# `search_conducted`). Which group is searched at the highest rate, and how
# does it compare with the rate for white drivers?

# %% [markdown]
# {{< pagebreak >}}

# %% [markdown]
# **4.2 (8 points).** A search-rate gap alone cannot say whether officers
# apply a lower bar of suspicion to some groups; maybe searches of every group
# are equally productive. Compute the **hit rate**: among stops where a search
# happened, the share where contraband was found, by `subject_race`. Present
# search rate and hit rate side by side.

# %% [markdown]
# {{< pagebreak >}}

# %% [markdown]
# **4.3 (6 points).** Interpret the two columns together in two or three
# sentences. If searches of one group both happen far more often **and** find
# contraband far less often, what does that pattern suggest about the
# threshold of suspicion applied to that group?

# %% [markdown]
# *Your answer:*

# %% [markdown]
# {{< pagebreak >}}

# %% [markdown]
# ## 5. Automate it across cities (16 points)

# %% [markdown]
# **5.1 (10 points).** Write a function `city_rates(path)` that takes a file
# path and returns the Section 4 table (stops, search rate, hit rate by race)
# with an added `city` column taken from the filename. Loop over
# `data/raw/*.csv.gz` with `glob`, collect the three tables, and combine them
# with `pd.concat` into one table.

# %% [markdown]
# {{< pagebreak >}}

# %% [markdown]
# **5.2 (6 points).** Using your combined table, report each city's
# black-to-white search-rate ratio. Which city shows the largest ratio, and
# which city's hit rates look closest to equal across groups?

# %% [markdown]
# {{< pagebreak >}}

# %% [markdown]
# ## 6. What these tables cannot say (10 points)

# %% [markdown]
# **6.1 (10 points).** Write three sentences, each naming one distinct limit.
# Consider what the denominator of a "stop rate" would need that these files
# lack, who assigns the `subject_race` label, and what three cities in
# 2010–2015 can represent.

# %% [markdown]
# *Your answer:*

# %% [markdown]
# {{< pagebreak >}}

# %% [markdown]
# ## Problem Set Reflections (10 points)
#
# Every problem set ends with these reflections. Answer them honestly. You are
# graded on the specificity and honesty in the reflections you show, not on how
# much AI you used or did not use. You cannot use AI for this part, and we are
# not checking for spelling or grammar. Write as much as each answer needs.
#
# Write your answer under each heading.

# %% [markdown]
# ### AI use
#
# List each substantive use of an AI assistant: the tool and model, what you
# asked for, what it gave back, how you checked it, and whether you kept or
# rejected the result. Write "None" if you used none.

# %% [markdown]
# *Your answer:*

# %% [markdown]
# ### People consulted
#
# Who you talked to about this assignment, and what about.

# %% [markdown]
# *Your answer:*

# %% [markdown]
# ### Where you got stuck
#
# The step that blocked you, and what got you unstuck.

# %% [markdown]
# *Your answer:*

# %% [markdown]
# ### What you understand now
#
# One thing you understand now that you did not when you started.

# %% [markdown]
# *Your answer:*

# %% [markdown]
# ### Hours spent
#
# An honest estimate of the time this took.

# %% [markdown]
# *Your answer:*

# %% [markdown]
# {{< pagebreak >}}

# %% [markdown]
# ## Appendix: where the data came from
#
# The three files come from the Stanford Open Policing Project, which collects
# and standardizes stop records from police departments across the United
# States (Pierson et al. 2020, "A large-scale analysis of racial disparities in
# police stops across the United States," *Nature Human Behaviour* 4: 736–745;
# openpolicing.stanford.edu).
#
# They hold vehicular stops in San Francisco, Charlotte, and Nashville dated
# 2010-01-01 through 2015-12-31, the window all three cities cover, with the
# twelve shared fields listed above.
